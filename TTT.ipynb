# %%
#ESTE FUE EL PRIMER CÓDIGO QUE ESCRIBIMOS


#Creamos un tablero. Como es un 3x3, determinamos un rango de 0 a 9 y lo separamos
#con lineas para que quede más estético:

tablero = [' ' for _ in range(9)] 

print("\n")
print(f"{tablero[0]} | {tablero[1]} | {tablero[2]}")
print("--+---+--")
print(f"{tablero[3]} | {tablero[4]} | {tablero[5]}")
print("--+---+--")
print(f"{tablero[6]} | {tablero[7]} | {tablero[8]}")
print("\n")

#Elegimos el nombre de cada jugadora:
nombre_jugadora_1 = input("Por favor, Jugadora 1, ingresa tu nombre.")
nombre_jugadora_2 = input("Por favor, Jugadora 2, ingresa tu nombre.")
#Elegimos con qué ficha empieza cada jugadora:
ficha_1 = "X"
ficha_2 = "O"
# Inicializar el turno actual con el nombre de la primera jugadora
turno_actual = nombre_jugadora_1
ficha_actual = ficha_1

#Condiciones para determinar ganadora:
while True: 
    #Mostrar de quién es el turno:
    print(f"Es el turno de {turno_actual}, tu ficha es {ficha_actual}")

    #Pedirle que haga su jugada:
    posicion = input("Elige una posición del 1 al 9, siendo 5 la posición central")
    print(posicion)


    if tablero is tablero[0] == tablero[1] == tablero[2] or \
    tablero[3] == tablero[4] == tablero[5] or \
    tablero[6] == tablero[7] == tablero[8] or \
    tablero[2] == tablero[3] == tablero[6] or \
    tablero[1] == tablero[4] == tablero[7] or \
    tablero[2] == tablero[5] == tablero[8] or \
    tablero[0] == tablero[4] == tablero[8] or \
    tablero[6] == tablero[4] == tablero[2]:
        
        
    print("Ha ganado el jugador {turno_actual}")
else:
# Out:
#   Cell In[34], line 44
#     print("Ha ganado el jugador {turno_actual}")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 34

# %%
#CÓDIGO CON TABLILLA NUMÉRICA


# Crear un tablero representado por los números del 1 al 9
tablero = [str(i + 1) for i in range(9)]

# Mostrar el tablero inicial con números para orientación
print("¡Bienvenidas al Tic Tac Toe! Estas son las posiciones que puedes jugar.")
print("\n")
print(f"{tablero[0]} | {tablero[1]} | {tablero[2]}")
print("--+---+--")
print(f"{tablero[3]} | {tablero[4]} | {tablero[5]}")
print("--+---+--")
print(f"{tablero[6]} | {tablero[7]} | {tablero[8]}")
print("\n")

# Elegimos el nombre de cada jugadora
nombre_jugadora_1 = input("Por favor, Jugadora 1, ingresa tu nombre: ")
nombre_jugadora_2 = input("Por favor, Jugadora 2, ingresa tu nombre: ")

# Elegimos con qué ficha empieza cada jugadora
ficha_1 = "X"
ficha_2 = "O"
turno_actual = nombre_jugadora_1
ficha_actual = ficha_1

# Condiciones para determinar ganadora
while True:
    # Mostrar de quién es el turno
    print(f"Es el turno de {turno_actual}, tu ficha es {ficha_actual}.")

    # Pedirle que haga su jugada
    posicion = input("Elige una posición del 1 al 9, siendo 5 la posición central: ")
    
    if not posicion.isdigit():
        print("Por favor, ingresa un número válido.")
        continue

    posicion = int(posicion) - 1
    if posicion < 0 or posicion > 8:
        print("Posición fuera de rango. Intenta de nuevo.")
        continue

    if tablero[posicion] in ['X', 'O']:
        print("Esa posición ya está ocupada. Intenta de nuevo.")
        continue

    # Actualizar el tablero con la ficha actual
    tablero[posicion] = ficha_actual

    # Mostrar el tablero actualizado
    print("\n")
    print(f"{tablero[0]} | {tablero[1]} | {tablero[2]}")
    print("--+---+--")
    print(f"{tablero[3]} | {tablero[4]} | {tablero[5]}")
    print("--+---+--")
    print(f"{tablero[6]} | {tablero[7]} | {tablero[8]}")
    print("\n")

    # Verificar condiciones de victoria
    if (
        (tablero[0] == tablero[1] == tablero[2] != ' ') or
        (tablero[3] == tablero[4] == tablero[5] != ' ') or
        (tablero[6] == tablero[7] == tablero[8] != ' ') or
        (tablero[0] == tablero[3] == tablero[6] != ' ') or
        (tablero[1] == tablero[4] == tablero[7] != ' ') or
        (tablero[2] == tablero[5] == tablero[8] != ' ') or
        (tablero[0] == tablero[4] == tablero[8] != ' ') or
        (tablero[6] == tablero[4] == tablero[2] != ' ')
    ):
        print(f"¡Ha ganado {turno_actual}!")
        break

    # Verificar empate
    if all(casilleros in ['X', 'O'] for casilleros in tablero):
        print("¡Es un empate!")
        break

    # Cambiar de turno
    if turno_actual == nombre_jugadora_1:
        turno_actual = nombre_jugadora_2
        ficha_actual = ficha_2
    else:
        turno_actual = nombre_jugadora_1
        ficha_actual = ficha_1
# Out:
# ¡Bienvenidas al Tic Tac Toe! Estas son las posiciones que puedes jugar.
#
#
# 1 | 2 | 3
# --+---+--
# 4 | 5 | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Alba, tu ficha es X.
#
#
# 1 | 2 | 3
# --+---+--
# 4 | X | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Ele, tu ficha es O.
#
#
# 1 | 2 | O
# --+---+--
# 4 | X | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Alba, tu ficha es X.
#
#
# 1 | X | O
# --+---+--
# 4 | X | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Ele, tu ficha es O.
#
#
# 1 | X | O
# --+---+--
# 4 | X | O
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Alba, tu ficha es X.
#
#
# 1 | X | O
# --+---+--
# 4 | X | O
# --+---+--
# 7 | X | 9
#
#
# ¡Ha ganado Alba!

# %%
#CÓDIGO CON COLORES


# Crear un tablero representado por los números del 1 al 9
tablero = [str(i + 1) for i in range(9)]

# Códigos de color ANSI
ROJO = "\033[31m"  # Rojo
VERDE = "\033[32m"  # Verde
RESET = "\033[0m"   # Resetear color

# Mostrar el tablero inicial con números para orientación
print("¡Bienvenidas al Tic Tac Toe! Estas son las posiciones que puedes jugar.")
print("\n")
print(f"{tablero[0]} | {tablero[1]} | {tablero[2]}")
print("--+---+--")
print(f"{tablero[3]} | {tablero[4]} | {tablero[5]}")
print("--+---+--")
print(f"{tablero[6]} | {tablero[7]} | {tablero[8]}")
print("\n")

# Elegimos el nombre de cada jugadora
nombre_jugadora_1 = input("Por favor, Jugadora 1, ingresa tu nombre: ")
nombre_jugadora_2 = input("Por favor, Jugadora 2, ingresa tu nombre: ")

# Elegimos con qué ficha empieza cada jugadora
ficha_1 = ROJO + "X" + RESET
ficha_2 = VERDE + "O" + RESET
turno_actual = nombre_jugadora_1
ficha_actual = ficha_1

# Condiciones para determinar ganadora
while True:
    # Mostrar de quién es el turno
    print(f"Es el turno de {turno_actual}, tu ficha es {ficha_actual}.")

    # Pedirle que haga su jugada
    posicion = input("Elige una posición del 1 al 9, siendo 5 la posición central: ")
    
    if not posicion.isdigit():
        print("Por favor, ingresa un número válido.")
        continue

    posicion = int(posicion) - 1
    if posicion < 0 or posicion > 8:
        print("Posición fuera de rango. Intenta de nuevo.")
        continue

    if tablero[posicion] in [ficha_1, ficha_2]:
        print("Esa posición ya está ocupada. Intenta de nuevo.")
        continue

    # Actualizar el tablero con la ficha actual
    tablero[posicion] = ficha_actual

    # Mostrar el tablero actualizado
    print("\n")
    print(f"{tablero[0]} | {tablero[1]} | {tablero[2]}")
    print("--+---+--")
    print(f"{tablero[3]} | {tablero[4]} | {tablero[5]}")
    print("--+---+--")
    print(f"{tablero[6]} | {tablero[7]} | {tablero[8]}")
    print("\n")

    # Verificar condiciones de victoria
    if (
        (tablero[0] == tablero[1] == tablero[2] != ' ') or
        (tablero[3] == tablero[4] == tablero[5] != ' ') or
        (tablero[6] == tablero[7] == tablero[8] != ' ') or
        (tablero[0] == tablero[3] == tablero[6] != ' ') or
        (tablero[1] == tablero[4] == tablero[7] != ' ') or
        (tablero[2] == tablero[5] == tablero[8] != ' ') or
        (tablero[0] == tablero[4] == tablero[8] != ' ') or
        (tablero[6] == tablero[4] == tablero[2] != ' ')
    ):
        print(f"¡Ha ganado {turno_actual}!")
        break

    # Verificar empate
    if all(casilleros in [ficha_1, ficha_2] for casilleros in tablero):
        print("¡Es un empate!")
        break

    # Cambiar de turno
    if turno_actual == nombre_jugadora_1:
        turno_actual = nombre_jugadora_2
        ficha_actual = ficha_2
    else:
        turno_actual = nombre_jugadora_1
        ficha_actual = ficha_1
# Out:
# ¡Bienvenidas al Tic Tac Toe! Estas son las posiciones que puedes jugar.
#
#
# 1 | 2 | 3
# --+---+--
# 4 | 5 | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Alba, tu ficha es X.
#
#
# 1 | 2 | 3
# --+---+--
# 4 | X | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Ele, tu ficha es O.
# Esa posición ya está ocupada. Intenta de nuevo.
# Es el turno de Ele, tu ficha es O.
#
#
# 1 | 2 | O
# --+---+--
# 4 | X | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Alba, tu ficha es X.
#
#
# X | 2 | O
# --+---+--
# 4 | X | 6
# --+---+--
# 7 | 8 | 9
#
#
# Es el turno de Ele, tu ficha es O.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 35
#      32 print(f"Es el turno de {turno_actual}, tu ficha es {ficha_actual}.")
#      34 # Pedirle que haga su jugada
# ---> 35 posicion = input("Elige una posición del 1 al 9, siendo 5 la posición central: ")
# ...
